# %%
import os
os.getcwd()
# Out:
# '/home/mulluken/Documents/enehoo/tomercato'

# %%
import pandas as pd

df = pd.read_excel (r'ngd mereja.xlsx') #place "r" before the path string to address special character, such as '\'. Don't forget to put the file name at the end of the path + '.xlsx'
print (df)
# Out:
#      LegalStatusNameAmhSource  \
# 0        ሃላፊነቱ የተወሰነ የግል ማህበር
# 1        ሃላፊነቱ የተወሰነ የግል ማህበር
# 2        ሃላፊነቱ የተወሰነ የግል ማህበር
# 3        ሃላፊነቱ የተወሰነ የግል ማህበር
# 4        ሃላፊነቱ የተወሰነ የግል ማህበር
# ...                       ...
# 1350                 ግለሰብ ነጋዴ
# 1351          የህብረት ሽርክና ማህበር
# 1352          የህብረት ሽርክና ማህበር
# 1353                 ግለሰብ ነጋዴ
# 1354                 ግለሰብ ነጋዴ
#
#                                         BusinessNameAmh amdescription  \
# 0                              አማጋ ኃላፊነቱ የተወሰነ የግል ኩባንያ        ኢትዮጵያዊ
# 1                                     ሙለጌ ኃ የተ የግል ማህበር        ኢትዮጵያዊ
# 2                       አልታ ኮምፒዩቴክ ኃላፊነቱ የተወሰነ የግል ማህበር        ኢትዮጵያዊ
# 3                 አዲስ ኤክስፖርተር ሊሚትድ ሀላፊነቱ የተወሰነ የግል ማህበር        ኢትዮጵያዊ
# 4                       ይርጋ ትሬዲንግ  ሀላፊነቱ የተወሰነ የግል ማህበር        ኢትዮጵያዊ
# ...                                                 ...           ...
# 1350                                        ዮሴፍ ደረጀ ለገሰ        ኢትዮጵያዊ
# ...

# %%
sheet_to_df_map = pd.read_excel('ngd mereja 2.xlsx', sheet_name=None)
mdf = pd.concat(sheet_to_df_map, axis=0, ignore_index=True)

# %%
mdf.count()
# Out:
# LegalStatusNameAmhSource    231147
# BusinessNameAmh             231147
# amdescription               231147
# WOREDA                      231147
# KEBELE                      231147
# HOUSE_NO                    231121
# Tel                         190537
# DateRegistered              231147
# PaidUpCapital               231147
# Description                 231147
# BusinessIn                  231147
# SiteID                      231147
# Status                      231147
# Sex                         231147
# Category                    231147
# dtype: int64

# %%
df.head()
# Out:
#   LegalStatusNameAmhSource                        BusinessNameAmh  \
# 0     ሃላፊነቱ የተወሰነ የግል ማህበር               አማጋ ኃላፊነቱ የተወሰነ የግል ኩባንያ
# 1     ሃላፊነቱ የተወሰነ የግል ማህበር                      ሙለጌ ኃ የተ የግል ማህበር
# 2     ሃላፊነቱ የተወሰነ የግል ማህበር        አልታ ኮምፒዩቴክ ኃላፊነቱ የተወሰነ የግል ማህበር
# 3     ሃላፊነቱ የተወሰነ የግል ማህበር  አዲስ ኤክስፖርተር ሊሚትድ ሀላፊነቱ የተወሰነ የግል ማህበር
# 4     ሃላፊነቱ የተወሰነ የግል ማህበር        ይርጋ ትሬዲንግ  ሀላፊነቱ የተወሰነ የግል ማህበር
#
#   amdescription   WOREDA  KEBELE   HOUSE_NO        Tel DateRegistered  \
# 0        ኢትዮጵያዊ  አዲስ ከተማ       1  1ኛ/ፎ/F1-7  911276048     2018-10-25
# 1        ኢትዮጵያዊ       ቦሌ       7        አዲስ  112772938     2015-06-09
# 2        ኢትዮጵያዊ     ቂርቆስ       1     988/06  115519546     2017-10-20
# 3        ኢትዮጵያዊ      አራዳ       2      738/ሀ  111561829     2014-07-29
# 4        ኢትዮጵያዊ  አቃቂ ቃሊቲ       5        አዲስ  911650467     2014-03-17
#
#    PaidUpCapital                       Description  \
# 0    120993000.0  1. ግብርና ፣አደን፣የደን ልማት እና የአሳ ማስገር
# ...

# %%
from pandas.io import sql
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="Muluken!2nega",
                               db="ngd"))
mdf.to_sql(con=engine, name='ngd_aa', if_exists='replace')

# %%
conda install sqlalchemy
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
