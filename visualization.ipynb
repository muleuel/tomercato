# %%
#1. check working directory and set if to the required dir
import os
os.getcwd()
# Out:
# '/home/mulluken/Documents/enehoo/tomercato'

# %%
conda install

# %%
#2. import data
import pymysql 
import pandas as pd

mysql_connection = pymysql.connect(host='127.0.0.1',
                    user='root',
                    password='Muluken!2nega',
                    db='tomercato',
                    charset='utf8',
                    cursorclass=pymysql.cursors.DictCursor)
                    
sql = "SELECT distinct * FROM `b_info` limit 100"
df = pd.read_sql(sql, mysql_connection)
df.describe()
# Out:
#        company sector     description  \
# count     3344   3344            3344
# unique    3316    382             324
# top             Hotel  \r\n\t\t\t\t\t
# freq         4    213            3018
#
#                                                   contact  \
# count                                                3344
# unique                                               3336
# top     Mobile +251 912 025172Mobile 2 +251 929 017903...
# freq                                                    2
#
#                                                    source
# count                                                3344
# unique                                               3340
# top     https://www.2merkato.com/directory/1786-camels...
# freq                                                    2

# %%
conda install pymysql
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#3. Visualize

import matplotlib.pyplot as plt
import pandas as pd

ax = df['sector'].value_counts().head(30).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number of companies per sector")
ax.set_xlabel("Sector")
ax.set_ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %%
conda install -c plotly plotly=4.9.0
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/mulluken/anaconda3
#
#   added / updated specs:
#     - plotly=4.9.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     plotly-4.9.0               |             py_0         5.8 MB  plotly
#     retrying-1.3.3             |             py_2          14 KB
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   plotly             plotly/noarch::plotly-4.9.0-py_0
#   retrying           pkgs/main/noarch::retrying-1.3.3-py_2
#
#
#
# ...
# plotly-4.9.0         | 5.8 MB    | ##################################### | 100%
# retrying-1.3.3       | 14 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# ...

# %%
conda install "notebook>=5.3" "ipywidgets=7.5"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

sector_count = df.groupby(['sector']).size().reset_index(name='counts').sort_values('counts', ascending=False).head(10)

fig = px.bar(sector_count, x='sector', y='counts')
fig.show()
#sector_count
# Out:
# <div>
#
#
#             <div id="764f10b7-f574-46af-a3d8-b5cb4e3531d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("764f10b7-f574-46af-a3d8-b5cb4e3531d6")) {
#                     Plotly.newPlot(
#                         '764f10b7-f574-46af-a3d8-b5cb4e3531d6',
# ...
